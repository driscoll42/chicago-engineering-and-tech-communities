# %%
from meetup import get_meetup_events
from mhub import get_mhub_events
from luma import get_luma_group_events
import pandas as pd
import gspread
from gspread_dataframe import set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials


# TODO: Get 1871 Events
# TODO: Get lu.ma Events
# TODO: Get Eventbrite Events
# TODO: Figure out the list of others that need to be scraped
# TODO: Figure out a way to make this format nicely for pasting into slack/discord
# TODO: Make a website/calendar

# %%
meetup_list = ['https://www.meetup.com/100devs-meetup-group/',
               'https://www.meetup.com/312-coders/',
               'https://www.meetup.com/ai-2030-responsible-artificial-intelligence/',
               'https://www.meetup.com/aittg-chicago/',
               'https://www.meetup.com/awenitechicago/',
               'https://www.meetup.com/aws-chicago/',
               'https://www.meetup.com/bitcoin-open-blockchain-community-chicago/',
               'https://www.meetup.com/blacks-united-in-leading-technology-chicago/',
               'https://www.meetup.com/burbsec/',
               'https://www.meetup.com/chibitdevs/',
               'https://www.meetup.com/chicago_bitcoin/',
               'https://www.meetup.com/chicago-ai-at-work/',
               'https://www.meetup.com/chicago-analytics-and-data-science-in-the-cloud/',
               'https://www.meetup.com/chicago-c-cpp-users-group/',
               'https://www.meetup.com/chicago-coworking-space-meetup-group/',
               'https://www.meetup.com/chicago-crypto-art/',
               'https://www.meetup.com/chicago-cyber-circle/',
               'https://www.meetup.com/chicago-dbt-meetup/',
               'https://www.meetup.com/chicago-food-tech/',
               'https://www.meetup.com/chicago-haskell/',
               'https://www.meetup.com/deai-chicago/',
               'https://www.meetup.com/chicago-html5/',
               'https://www.meetup.com/chicago-indie-hackers/',
               'https://www.meetup.com/chicago-kotlin/',
               'https://www.meetup.com/chicago-machine-learning-paper-reading-group/',
               'https://www.meetup.com/chicago-ml-data-science/',
               'https://www.meetup.com/Chicago-ML/',
               'https://www.meetup.com/chicago-open-hack/',
               'https://www.meetup.com/chicago-open-source-data-infrastructure-meetup/',
               'https://www.meetup.com/chicago-postgresql-user-group/',
               'https://www.meetup.com/chicago-r-user-group/',
               'https://www.meetup.com/chicago-seleniumistas/',
               'https://www.meetup.com/chicago-snowflake-users/',
               'https://www.meetup.com/chicago-startup-founder-101/',
               'https://www.meetup.com/chicago-suburban-sql-user-group/',
               'https://www.meetup.com/chicago-unreal-engine-heroes/',
               'https://www.meetup.com/chicago-women-ux-designers-in-tech/',
               'https://www.meetup.com/chicagodataprofessionals/',
               'https://www.meetup.com/chicagodesignsystems/',
               'https://www.meetup.com/chicagogo/',
               'https://www.meetup.com/chicagojug/',
               'https://www.meetup.com/chicagolandpowerbi/',
               'https://www.meetup.com/chicagoleanstartup/',
               'https://www.meetup.com/chicagomldsdev/',
               'https://www.meetup.com/chicagoruby/',
               'https://www.meetup.com/chicagotechmixer/',
               'https://www.meetup.com/chipma/',
               'https://www.meetup.com/chitownbio/',
               'https://www.meetup.com/code-and-coffee-chicago/',
               'https://www.meetup.com/couchbase-midwest/',
               'https://www.meetup.com/creativeai-chicago/',
               'https://www.meetup.com/deep-dish-rust/',
               'https://www.meetup.com/devops/',
               'https://www.meetup.com/digital-commerce-meetup-group/',
               'https://www.meetup.com/discover-technology/',
               'https://www.meetup.com/drupalchicago/',
               'https://www.meetup.com/elastic-chicago-user-group/',
               'https://www.meetup.com/founder-s-therapy-chicago/',
               'https://www.meetup.com/grafana-and-friends-chicago/',
               'https://www.meetup.com/issa-chicago-chapter/',
               'https://www.meetup.com/IxDAChicago/',
               'https://www.meetup.com/js-chi/',
               'https://www.meetup.com/meetup-group-tyemzklu/',
               'https://www.meetup.com/nerp-not-exclusively-raspberry-pi/',
               'https://www.meetup.com/nscoder-chicago/',
               'https://www.meetup.com/open-code-chicago/',
               'https://www.meetup.com/opensearch-project-chicago/',
               'https://www.meetup.com/oravew-fire/',
               'https://www.meetup.com/pydatachi/',
               'https://www.meetup.com/queer-tech-club/',
               'https://www.meetup.com/react-chicago/',
               'https://www.meetup.com/rhug-chicago/',
               'https://www.meetup.com/rladies-chicago/',
               'https://www.meetup.com/rmfs-chicago/',
               'https://www.meetup.com/signalwire-code-and-connect-ai-low-code-and-networking/',
               'https://www.meetup.com/tech-salon-chicago/',
               'https://www.meetup.com/ukrainian-it-cluster/',
               'https://www.meetup.com/uniforum-chicago/',
               'https://www.meetup.com/uxchicago/',
               'https://www.meetup.com/uxsynergies/'
               'https://www.meetup.com/vrarchicago/',
               'https://www.meetup.com/wclug-org/'
               ]

luma_groups = ['https://lu.ma/chicago-mlops', 'https://lu.ma/wilsonsonsini', 'https://lu.ma/munitech',
               'https://lu.ma/thecomputecollective']

# %%
meetup_df = get_meetup_events(meetup_list, sleep_time=2, verbose=False, debug=True)
mhub_df = get_mhub_events()
luma_df = get_luma_group_events(luma_groups, sleep_time=2, verbose=False, debug=True)

# %%
# combine the dataframes
# combined_df = pd.concat([meetup_df, mhub_df, luma_df], ignore_index=True)
combined_df = pd.concat([mhub_df, luma_df], ignore_index=True)
combined_df
# Out:
#                                             eventName  \
# 0        mHOUSE - Live DJ at mHUB partnered with V2VC
# 1                   HardTech Startup and Investor Day
# 2             Ask Me Anything - Intellectual Property
# 3      Empower to Grow Program - SBA Program Overview
# 4                         Women in Manufacturing 2024
# 5                               Portfolio Development
# 6   Market Sizing and Customer Mapping + Financial...
# 7               Core Messaging and Anatomy of a Pitch
# 8     Foundations for Founders - Entity Formation 101
# 9           MLOps Community / Chicago ML joint meetup
# 10                             MuniTech 2024: Chicago
# 11  Chicago Digital Health Tech (Chicago DHT) Brea...
#
#                                              eventURL  \
# 0   https://www.mhubchicago.com/events/mhouse---li...
# 1   https://www.mhubchicago.com/events/hardtech-st...
# 2   https://www.mhubchicago.com/events/ask-me-anyt...
# ...

# %%
# Authenticate and initialize the Google Sheets client
scope = ["https://spreadsheets.google.com/feeds", "https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("chicago-events-435701-b0daa42d7c25.json", scope)
client = gspread.authorize(creds)

# %%
# Open the Google Sheet and select a specific worksheet by title
spreadsheet = client.open("Chicago Engineering Community Sheet")
sheet = spreadsheet.worksheet("Events")  # Replace with your sheet title

# Get existing data from the sheet
existing_data = pd.DataFrame(sheet.get_all_records())
existing_data
# Out:
#   eventName eventURL eventStartTime eventendTime eventVenueName eventAddress  \
# 0      asdf     asdf
#
#   eventCity eventState groupName eventGoogleMaps event_description
# 0

# %%
# Optional: Specify the key columns to identify duplicates (e.g., a unique ID or a combination of columns)
key_columns = ["eventURL"]

# Remove duplicates by checking for existing records in the sheet
# Use pandas merge to find the difference between existing and new data
merged = pd.merge(combined_df, existing_data, how='left', on=key_columns, indicator=True)
new_only = merged[merged['_merge'] == 'left_only'].drop(columns=['_merge'])

# If there are any new records to append
if not new_only.empty:
    # Find the starting row for appending (after the existing data)
    next_row = len(existing_data) + 2  # Add 2 because index starts from 0 and there's a header row

    # Append the new data to the Google Sheet
    set_with_dataframe(sheet, new_only, row=next_row)
else:
    print("No new records to append")

# %%
merged
# Out:
#                                           eventName_x  \
# 0        mHOUSE - Live DJ at mHUB partnered with V2VC
# 1                   HardTech Startup and Investor Day
# 2             Ask Me Anything - Intellectual Property
# 3      Empower to Grow Program - SBA Program Overview
# 4                         Women in Manufacturing 2024
# 5                               Portfolio Development
# 6   Market Sizing and Customer Mapping + Financial...
# 7               Core Messaging and Anatomy of a Pitch
# 8     Foundations for Founders - Entity Formation 101
# 9           MLOps Community / Chicago ML joint meetup
# 10                             MuniTech 2024: Chicago
# 11  Chicago Digital Health Tech (Chicago DHT) Brea...
#
#                                              eventURL  \
# 0   https://www.mhubchicago.com/events/mhouse---li...
# 1   https://www.mhubchicago.com/events/hardtech-st...
# 2   https://www.mhubchicago.com/events/ask-me-anyt...
# ...
